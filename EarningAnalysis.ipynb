# %% [markdown]
# <a href="https://colab.research.google.com/github/Paritosh0007/Earning-Analysis/blob/master/EarningAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv("/content/drive/My Drive/Visualizing-Earnings-Based-On-College-Majors-master/recent-grads.csv")

# %%
recent_grads.head()
# Out:
#    Rank  Major_code  ... Non_college_jobs  Low_wage_jobs
# 0     1        2419  ...              364            193
# 1     2        2416  ...              257             50
# 2     3        2415  ...              176              0
# 3     4        2417  ...              102              0
# 4     5        2405  ...             4440            972
#
# [5 rows x 21 columns]

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code  ... Non_college_jobs  Low_wage_jobs
# 168   169        3609  ...             2947            743
# 169   170        5201  ...              615             82
# 170   171        5202  ...              870            622
# 171   172        5203  ...             1245            308
# 172   173        3501  ...              338            192
#
# [5 rows x 21 columns]

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code  ...  Non_college_jobs  Low_wage_jobs
# count  173.000000   173.000000  ...        173.000000     173.000000
# mean    87.000000  3879.815029  ...      13284.497110    3859.017341
# std     50.084928  1687.753140  ...      23789.655363    6944.998579
# min      1.000000  1100.000000  ...          0.000000       0.000000
# 25%     44.000000  2403.000000  ...       1591.000000     340.000000
# 50%     87.000000  3608.000000  ...       4595.000000    1231.000000
# 75%    130.000000  5503.000000  ...      11783.000000    3466.000000
# max    173.000000  6403.000000  ...     148395.000000   48207.000000
#
# [8 rows x 19 columns]

# %%
recent_grads.shape
# Out:
# (173, 21)

# %%
recent_grads = recent_grads.dropna()

# %%
recent_grads.shape
# Out:
# (172, 21)

# %%
recent_grads.plot(x='Total',y='Median',kind='scatter')

# %%
recent_grads.plot(x='Sample_size',y='Unemployment_rate',kind='scatter')

# %%
recent_grads.plot(x='Full_time',y='Median',kind='scatter')

# %%
recent_grads.plot(x='ShareWomen',y='Unemployment_rate',kind='scatter')

# %%
recent_grads.plot(x='Men',y='Median',kind='scatter')

# %%
recent_grads.plot(x='Women',y='Median',kind='scatter')

# %%
recent_grads.plot(x='ShareWomen',y='Median',kind='scatter')

# %%
recent_grads['Sample_size'].plot(kind='hist')

# %%
recent_grads['ShareWomen'].hist(bins=25,range=(0,0.5))

# %%
recent_grads['ShareWomen'].hist(bins=25,range=(0.5,1))

# %%
recent_grads['Men'].plot(kind='hist')

# %%
recent_grads['ShareWomen'].hist(bins=25,range=(0,0.5))

# %%
recent_grads['ShareWomen'].hist(bins=25,range=(0.5,1))

# %%
recent_grads['Men'].plot(kind='hist')

# %%
recent_grads['Women'].plot(kind='hist')

# %%
recent_grads['Median'].hist(bins=25,range=(20000,40000))

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f97e1756f60>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f97e152de10>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Total', 'Men', 'Women']],figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f97e125af28>,
# ...
#       dtype=object)

# %%
recent_grads[:10]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[-10:]['ShareWomen'].plot(kind='bar')

# %%
recent_grads[:10]['Unemployment_rate'].plot(kind='bar')

# %%
recent_grads[-10:]['Unemployment_rate'].plot(kind='bar')

# %%
recent_grads[:20].plot.bar(x='Major',y=['Men','Women'])
